# %%
import pandas as pd

# %%
df = pd.read_csv('./r1AllFlights.csv', index_col = 0, header = 0)
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#    YEAR  MONTH  DAY_OF_WEEK UNIQUE_CARRIER ORIGIN ORIGIN_STATE_ABR DEST  \
# 0  2010      1            6             9E    ATL               GA  AUS
# 1  2010      1            6             9E    ATL               GA  AUS
# 2  2010      1            6             9E    ATL               GA  AUS
# 3  2010      1            6             9E    ATL               GA  AUS
# 4  2010      1            2             9E    ATL               GA  RDU
#
#   DEST_STATE_ABR  CRS_DEP_TIME  CRS_ELAPSED_TIME  DISTANCE  LABEL
# 0             TX        1056.0             154.0     813.0      1
# 1             TX        1056.0             154.0     813.0      1
# 2             TX        1056.0             154.0     813.0      0
# ...

# %%
df_aggregated = df.groupby(by=['ORIGIN','DEST', 'YEAR','LABEL'], squeeze=True).count()
df_aggregated
# Out:
#                         MONTH  DAY_OF_WEEK  UNIQUE_CARRIER  ORIGIN_STATE_ABR  \
# ORIGIN DEST YEAR LABEL
# ABE    ATL  2010 0        437          437             437               437
#                  1         74           74              74                74
#                  3          8            8               8                 8
#             2011 0        545          545             545               545
#                  1        129          129             129               129
#                  2          4            4               4                 4
#                  3         28           28              28                28
#             2012 0        414          414             414               414
#                  1         36           36              36                36
#                  2          2            2               2                 2
#                  3          2            2               2                 2
# ...

# %%
df_aggregated.to_csv('./AllFlightsGrouped.csv')

# %%
df2 = df.drop_duplicates(subset='DEST', keep='first')

# %%
df2[['DEST', 'ORIGIN']].to_csv('./airportconnectionreverse.csv', header=False, index = False)
